# %%
import pandas as pd

# %%
df=pd.read_csv("PokemonDataSet.csv")

# %%
df.head()
# Out:
#    National_Dex        Name Type_1  Type_2  Total_Base_Stats  HP  Attack  \
# 0             1   Bulbasaur  Grass  Poison               318  45      49
# 1             2     Ivysaur  Grass  Poison               405  60      62
# 2             3    Venusaur  Grass  Poison               525  80      82
# 3             4  Charmander   Fire     NaN               309  39      52
# 4             5  Charmeleon   Fire     NaN               405  58      64
#
#    Defense  Sp_Atk  Sp_Def  Speed  Generation  Height_m  Weight_kg  \
# 0       49      65      65     45           1       0.7        6.9
# 1       63      80      80     60           1       1.0       13.0
# 2       83     100     100     80           1       2.0      100.0
# 3       43      60      50     65           1       0.6        8.5
# 4       58      80      65     80           1       1.1       19.0
#
#    Catch_Rate Legendary_Status
# 0          45            False
# 1          45            False
# ...

# %%
df.query("Attack > 150")
# Out:
#      National_Dex       Name  Type_1 Type_2  Total_Base_Stats   HP  Attack  \
# 288           289    Slaking  Normal    NaN               670  150     160
# 408           409  Rampardos    Rock    NaN               495   97     165
# 485           486  Regigigas  Normal    NaN               670  110     160
#
#      Defense  Sp_Atk  Sp_Def  Speed  Generation  Height_m  Weight_kg  \
# 288      100      95      65    100           3       2.0      130.5
# 408       60      65      50     58           4       1.6      102.5
# 485      110      80     110    100           4       3.7      420.0
#
#      Catch_Rate Legendary_Status
# 288          45            False
# 408          45            False
# 485           3        Legendary

# %%
df.query("Speed <=10")
# Out:
#      National_Dex      Name  Type_1 Type_2  Total_Base_Stats   HP  Attack  \
# 212           213   Shuckle     Bug   Rock               505   20      10
# 327           328  Trapinch  Ground    NaN               290   45     100
# 437           438    Bonsly    Rock    NaN               290   50      80
# 445           446  Munchlax  Normal    NaN               390  135      85
#
#      Defense  Sp_Atk  Sp_Def  Speed  Generation  Height_m  Weight_kg  \
# 212      230      10     230      5           2       0.6       20.5
# 327       45      45      45     10           3       0.7       15.0
# 437       95      10      45     10           4       0.5       15.0
# 445       40      40      85      5           4       0.6      105.0
#
#      Catch_Rate Legendary_Status
# 212         190            False
# 327         255            False
# 437          45            False
# 445          50            False

# %%
df.loc[df["Speed"]<=10]
# Out:
#      National_Dex      Name  Type_1 Type_2  Total_Base_Stats   HP  Attack  \
# 212           213   Shuckle     Bug   Rock               505   20      10
# 327           328  Trapinch  Ground    NaN               290   45     100
# 437           438    Bonsly    Rock    NaN               290   50      80
# 445           446  Munchlax  Normal    NaN               390  135      85
#
#      Defense  Sp_Atk  Sp_Def  Speed  Generation  Height_m  Weight_kg  \
# 212      230      10     230      5           2       0.6       20.5
# 327       45      45      45     10           3       0.7       15.0
# 437       95      10      45     10           4       0.5       15.0
# 445       40      40      85      5           4       0.6      105.0
#
#      Catch_Rate Legendary_Status
# 212         190            False
# 327         255            False
# 437          45            False
# 445          50            False

# %%
len(df.query("Attack > 150"))
# Out:
# 3

# %%
df["Attack"]>150
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: Attack, Length: 500, dtype: bool

# %%
slow_pokemon_df=df.query("Speed <=10")
print(len(slow_pokemon_df))
# Out:
# 4

# %%
len(df.query("Sp_Def <=25"))
# Out:
# 15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   National_Dex      500 non-null    int64
#  1   Name              500 non-null    object
#  2   Type_1            500 non-null    object
#  3   Type_2            240 non-null    object
#  4   Total_Base_Stats  500 non-null    int64
#  5   HP                500 non-null    int64
#  6   Attack            500 non-null    int64
#  7   Defense           500 non-null    int64
#  8   Sp_Atk            500 non-null    int64
#  9   Sp_Def            500 non-null    int64
#  10  Speed             500 non-null    int64
#  11  Generation        500 non-null    int64
#  12  Height_m          500 non-null    float64
#  13  Weight_kg         500 non-null    float64
#  14  Catch_Rate        500 non-null    int64
#  15  Legendary_Status  500 non-null    object
# ...

# %%
legendary_df=df.query("Legendary_Status == 'Legendary'")
print(legendary_df.shape)
# Out:
# (26, 16)

# %%
df.sort_values(by='Defense',ascending=False).head()
# Out:
#      National_Dex      Name Type_1  Type_2  Total_Base_Stats  HP  Attack  \
# 212           213   Shuckle    Bug    Rock               505  20      10
# 376           377  Regirock   Rock     NaN               580  80     100
# 207           208   Steelix  Steel  Ground               510  75      85
# 305           306    Aggron  Steel    Rock               530  70     110
# 90             91  Cloyster  Water     Ice               525  50      95
#
#      Defense  Sp_Atk  Sp_Def  Speed  Generation  Height_m  Weight_kg  \
# 212      230      10     230      5           2       0.6       20.5
# 376      200      50     100     50           3       1.7      230.0
# 207      200      55      65     30           2       9.2      400.0
# 305      180      60      60     50           3       2.1      360.0
# 90       180      85      45     70           1       1.5      132.5
#
#      Catch_Rate Legendary_Status
# 212         190            False
# 376           3        Legendary
# ...

# %%
#multiple value sorting here asending 1st one is applied on the Defence and true will appy on the Attack

# %%
df.sort_values(by=["Defense","Attack"],ascending=[False,True]).head()
# Out:
#      National_Dex      Name Type_1  Type_2  Total_Base_Stats  HP  Attack  \
# 212           213   Shuckle    Bug    Rock               505  20      10
# 207           208   Steelix  Steel  Ground               510  75      85
# 376           377  Regirock   Rock     NaN               580  80     100
# 90             91  Cloyster  Water     Ice               525  50      95
# 305           306    Aggron  Steel    Rock               530  70     110
#
#      Defense  Sp_Atk  Sp_Def  Speed  Generation  Height_m  Weight_kg  \
# 212      230      10     230      5           2       0.6       20.5
# 207      200      55      65     30           2       9.2      400.0
# 376      200      50     100     50           3       1.7      230.0
# 90       180      85      45     70           1       1.5      132.5
# 305      180      60      60     50           3       2.1      360.0
#
#      Catch_Rate Legendary_Status
# 212         190            False
# 207          25            False
# ...

# %%
df.query("Defense > 200 and  Attack <15")
# Out:
#      National_Dex     Name Type_1 Type_2  Total_Base_Stats  HP  Attack  \
# 212           213  Shuckle    Bug   Rock               505  20      10
#
#      Defense  Sp_Atk  Sp_Def  Speed  Generation  Height_m  Weight_kg  \
# 212      230      10     230      5           2       0.6       20.5
#
#      Catch_Rate Legendary_Status
# 212         190            False

# %%
#df query with multiple condition

# %%
df.query(("Defense > 200")and("Attack <15"))
# Out:
#      National_Dex      Name  Type_1 Type_2  Total_Base_Stats   HP  Attack  \
# 112           113   Chansey  Normal    NaN               450  250       5
# 128           129  Magikarp   Water    NaN               200   20      10
# 212           213   Shuckle     Bug   Rock               505   20      10
# 241           242   Blissey  Normal    NaN               540  255      10
# 439           440   Happiny  Normal    NaN               220  100       5
#
#      Defense  Sp_Atk  Sp_Def  Speed  Generation  Height_m  Weight_kg  \
# 112        5      35     105     50           1       1.1       34.6
# 128       55      15      20     80           1       0.9       10.0
# 212      230      10     230      5           2       0.6       20.5
# 241       10      75     135     55           2       1.5       46.8
# 439        5      15      65     30           4       0.6       24.4
#
#      Catch_Rate Legendary_Status
# 112          30            False
# 128         255            False
# ...

# %%
# fire + flying
# need to check type 1 =fire type2 = flying

# %%
len(df.query("Type_1=='Fire' and Type_2=='Flying'"))
# Out:
# 3

# %%
df.loc[(
    (df["Type_1"]=="Fire")&
    (df["Type_2"]=="Flying")
)]
# Out:
#      National_Dex       Name Type_1  Type_2  Total_Base_Stats   HP  Attack  \
# 5               6  Charizard   Fire  Flying               534   78      84
# 145           146    Moltres   Fire  Flying               580   90     100
# 249           250      Ho-Oh   Fire  Flying               680  106     130
#
#      Defense  Sp_Atk  Sp_Def  Speed  Generation  Height_m  Weight_kg  \
# 5         78     109      85    100           1       1.7       90.5
# 145       90     125      85     90           1       2.0       60.0
# 249       90     110     154     90           2       3.8      199.0
#
#      Catch_Rate Legendary_Status
# 5            45            False
# 145           3        Legendary
# 249           3        Legendary

# %%
# How many Poison Pokemon in any of type_1 or Type_2

# %%
len(df.query("Type_1=='Poison' or Type_2=='Poison'"))
# Out:
# 52

# %%
# using df.loc

# %%
len(df.loc[(df["Type_1"]=="Poison") | (df["Type_2"]=="Poison")])
# Out:
# 52

# %%
# what type of pokemon Type_1 Ice has strongest defence
# type_1 ice and we need to find the max defence pokemon from the list

# %%
IcePokemon=df.query("Type_1=='Ice'")
IcePokemon.loc[IcePokemon["Defense"]==IcePokemon["Defense"].max()]
# Out:
#      National_Dex     Name Type_1 Type_2  Total_Base_Stats  HP  Attack  \
# 470           471  Glaceon    Ice    NaN               525  65      60
#
#      Defense  Sp_Atk  Sp_Def  Speed  Generation  Height_m  Weight_kg  \
# 470      110     130      95     65           4       0.8       25.9
#
#      Catch_Rate Legendary_Status
# 470          45            False

# %%
df.loc[df["Type_1"] == "Ice"].nlargest(1, "Defense")

# here we are filtering out first 1 element if we want 2 we give 2 instead of 1
# Out:
#      National_Dex     Name Type_1 Type_2  Total_Base_Stats  HP  Attack  \
# 470           471  Glaceon    Ice    NaN               525  65      60
#
#      Defense  Sp_Atk  Sp_Def  Speed  Generation  Height_m  Weight_kg  \
# 470      110     130      95     65           4       0.8       25.9
#
#      Catch_Rate Legendary_Status
# 470          45            False

# %%
# What is the most common type_1 of legendary Pokemons

# %%
df.head()
# Out:
#    National_Dex        Name Type_1  Type_2  Total_Base_Stats  HP  Attack  \
# 0             1   Bulbasaur  Grass  Poison               318  45      49
# 1             2     Ivysaur  Grass  Poison               405  60      62
# 2             3    Venusaur  Grass  Poison               525  80      82
# 3             4  Charmander   Fire     NaN               309  39      52
# 4             5  Charmeleon   Fire     NaN               405  58      64
#
#    Defense  Sp_Atk  Sp_Def  Speed  Generation  Height_m  Weight_kg  \
# 0       49      65      65     45           1       0.7        6.9
# 1       63      80      80     60           1       1.0       13.0
# 2       83     100     100     80           1       2.0      100.0
# 3       43      60      50     65           1       0.6        8.5
# 4       58      80      65     80           1       1.1       19.0
#
#    Catch_Rate Legendary_Status
# 0          45            False
# 1          45            False
# ...

# %%
df.query("Legendary_Status != 'False'").head()
# Out:
#      National_Dex      Name    Type_1  Type_2  Total_Base_Stats   HP  Attack  \
# 143           144  Articuno       Ice  Flying               580   90      85
# 144           145    Zapdos  Electric  Flying               580   90      90
# 145           146   Moltres      Fire  Flying               580   90     100
# 149           150    Mewtwo   Psychic     NaN               680  106     110
# 150           151       Mew   Psychic     NaN               600  100     100
#
#      Defense  Sp_Atk  Sp_Def  Speed  Generation  Height_m  Weight_kg  \
# 143      100      95     125     85           1       1.7       55.4
# 144       85     125      90    100           1       1.6       52.6
# 145       90     125      85     90           1       2.0       60.0
# 149       90     154      90    130           1       2.0      122.0
# 150      100     100     100    100           1       0.4        4.0
#
#      Catch_Rate Legendary_Status
# 143           3        Legendary
# ...

# %%
df.loc[df["Legendary_Status"]!="False","Type_1"].value_counts()
# Out:
# Type_1
# Psychic     10
# Water        5
# Fire         4
# Dragon       3
# Steel        3
# Electric     2
# Ice          2
# Normal       2
# Rock         1
# Ground       1
# Ghost        1
# Dark         1
# Grass        1
# Name: count, dtype: int64

# %%
df.loc[df["Legendary_Status"]!="False","Type_2"].value_counts()
# Out:
# Type_2
# Flying     6
# Psychic    3
# Dragon     3
# Grass      1
# Steel      1
# Fire       1
# Name: count, dtype: int64

# %%
(df.loc[df["Legendary_Status"] != "False", "Type_1"] + "/" +
 df.loc[df["Legendary_Status"] != "False", "Type_2"].fillna("")
)
# Out:
# 143         Ice/Flying
# 144    Electric/Flying
# 145        Fire/Flying
# 149           Psychic/
# 150           Psychic/
# 242          Electric/
# 243              Fire/
# 244             Water/
# 248     Psychic/Flying
# 249        Fire/Flying
# 250      Psychic/Grass
# 376              Rock/
# 377               Ice/
# 378             Steel/
# 379     Dragon/Psychic
# 380     Dragon/Psychic
# 381             Water/
# 382            Ground/
# 383      Dragon/Flying
# 384      Steel/Psychic
# 385           Psychic/
# 479           Psychic/
# 480           Psychic/
# 481           Psychic/
# 482       Steel/Dragon
# 483       Water/Dragon
# 484         Fire/Steel
# 485            Normal/
# 486       Ghost/Dragon
# 487           Psychic/
# 488             Water/
# 489             Water/
# 490              Dark/
# 491             Grass/
# 492            Normal/
# 493       Psychic/Fire
# dtype: object

# %%
df.loc[df["Legendary_Status"]!="False","Type_1"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Type_1'>

# %%
# most power full pokemon form the list by total type "water"

# %%
df.query("(Type_1 == 'Water' or Type_2 == 'Water') and Generation in [1, 2, 3]").nlargest(1, "Total_Base_Stats")
# Out:
#      National_Dex    Name Type_1 Type_2  Total_Base_Stats   HP  Attack  \
# 381           382  Kyogre  Water    NaN               670  100     100
#
#      Defense  Sp_Atk  Sp_Def  Speed  Generation  Height_m  Weight_kg  \
# 381       90     150     140     90           3       4.5      352.0
#
#      Catch_Rate Legendary_Status
# 381           5        Legendary

# %%
# powerful dragon from the last 2 generation that is 4 and 5

# %%
df["Generation"].value_counts()
df.query("(Type_1 == 'Dragon' or Type_2 == 'Dragon') and Generation in [4,5]").nlargest(1, "Total_Base_Stats")
# Out:
#      National_Dex    Name Type_1  Type_2  Total_Base_Stats   HP  Attack  \
# 482           483  Dialga  Steel  Dragon               680  100     120
#
#      Defense  Sp_Atk  Sp_Def  Speed  Generation  Height_m  Weight_kg  \
# 482      120     150     100     90           4       5.4      683.0
#
#      Catch_Rate Legendary_Status
# 482          30        Legendary

# %%
# Select pokemon that have an attack value above 100 and type 1 equals to fire

# %%
df.query("Attack > 100 and Type_1=='Fire' ")
# Out:
#      National_Dex       Name Type_1    Type_2  Total_Base_Stats   HP  Attack  \
# 58             59   Arcanine   Fire       NaN               555   90     110
# 135           136    Flareon   Fire       NaN               525   65     130
# 243           244      Entei   Fire       NaN               580  115     115
# 249           250      Ho-Oh   Fire    Flying               680  106     130
# 256           257   Blaziken   Fire  Fighting               530   80     120
# 391           392  Infernape   Fire  Fighting               534   76     104
# 499           500     Emboar   Fire  Fighting               528  110     123
#
#      Defense  Sp_Atk  Sp_Def  Speed  Generation  Height_m  Weight_kg  \
# 58        80     100      80     95           1       1.9      155.0
# 135       60      95     110     65           1       0.9       25.0
# 243       85      90      75    100           2       2.1      198.0
# 249       90     110     154     90           2       3.8      199.0
# ...

# %%
#select those pokemons that are Type_1 water and Type2 Flying. Store the selection in the variable Water_flying_df

# %%
Water_flying_df=df.query("Type_1=='Water'and Type_2=='Flying' ")
print(Water_flying_df)
# Out:
#      National_Dex      Name Type_1  Type_2  Total_Base_Stats  HP  Attack  \
# 129           130  Gyarados  Water  Flying               540  95     125
# 225           226   Mantine  Water  Flying               465  85      40
# 277           278   Wingull  Water  Flying               270  40      30
# 278           279  Pelipper  Water  Flying               440  60      50
# 457           458   Mantyke  Water  Flying               345  45      20
#
#      Defense  Sp_Atk  Sp_Def  Speed  Generation  Height_m  Weight_kg  \
# 129       79      60     100     81           1       6.5      235.0
# 225       70      80     140     70           2       2.1      220.0
# 277       30      55      30     85           3       0.6        9.5
# 278      100      95      70     65           3       1.2       28.0
# 457       50      60     120     50           4       1.0       65.0
#
#      Catch_Rate Legendary_Status
# 129          45            False
# 225          25            False
# ...

# %%
# Perform a selection in your Dataframe of all the legendary pokemons that are of type1 Fire. But Select only Columns Name,Attack and Generation. Store the results in a variable legendary_fire_df

# %%
df.head()
# Out:
#    National_Dex        Name Type_1  Type_2  Total_Base_Stats  HP  Attack  \
# 0             1   Bulbasaur  Grass  Poison               318  45      49
# 1             2     Ivysaur  Grass  Poison               405  60      62
# 2             3    Venusaur  Grass  Poison               525  80      82
# 3             4  Charmander   Fire     NaN               309  39      52
# 4             5  Charmeleon   Fire     NaN               405  58      64
#
#    Defense  Sp_Atk  Sp_Def  Speed  Generation  Height_m  Weight_kg  \
# 0       49      65      65     45           1       0.7        6.9
# 1       63      80      80     60           1       1.0       13.0
# 2       83     100     100     80           1       2.0      100.0
# 3       43      60      50     65           1       0.6        8.5
# 4       58      80      65     80           1       1.1       19.0
#
#    Catch_Rate Legendary_Status
# 0          45            False
# 1          45            False
# ...

# %%
# df.loc[(condition for Index),(Coilumns that need to be displayed)]
legendary_fire_df=df.loc[((df["Legendary_Status"]!='False') & (df['Type_1']=="Fire")),["Name","Attack"]]
legendary_fire_df
# Out:
#         Name  Attack
# 145  Moltres     100
# 243    Entei     115
# 249    Ho-Oh     130
# 484  Heatran      90

# %%
#Select slow and fast pokemons
